# %%
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
path = ''
def plot(dataset, name, path, size = 5):
    for i in range(size**2):
        plt.subplot(size,size,i + 1)
        plt.axis('off')
        plt.imshow(dataset[i],cmap = 'gray')
    plt.savefig('{}{}.png'.format(path,name))
    
generators = os.listdir(path)

for name in generators:
    gen = tf.keras.models.load_model(r'GAN/{}/Models/{}'.format(dirr,name))
    imgs = gen.predict(np.random.uniform(-1,1,(25,100)).reshape(25,1,1,100))
    plot(imgs, name)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-6050501ead3f> in <module>
#      11 for name in generators:
#      12     gen = tf.keras.models.load_model(r'GAN/{}/Models/{}'.format(dirr,name))
# ---> 13     imgs = gen.predict(np.random.uniform(-1,1,(25,100)).reshape(25,1,1,100))
#      14     plot(imgs, name)
#
# ~\anaconda3\envs\kaggles\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
# ...
